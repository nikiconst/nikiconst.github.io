# %% [markdown]
# <a href="https://colab.research.google.com/github/nikiconst/nikiconst.github.io/blob/main/week5_h_w.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# // ONS DOWNLOADER
import requests
import json
from google.colab import files

url_base = "https://api.ons.gov.uk/timeseries/{}/dataset/LMS/data"
file_base = "data_ONS-{}.json"
onsSeries = ['JWR5', 'JWR6', 'JWR7', 'JWR8', 'JWR9', 'JWS2', 'JWS3','JWS4','JWS5']

for i in onsSeries:  
    print("------Iteration Starts--------")
    print(i) 
  
   # // Build the URL for this iteration of the loop, and check what we are getting:
    URL = url_base.format(i)
    print(URL)
   
   # // Request the html from the URL:
    data = requests.get(URL).json()
    print(data)

   # // Set the filename, and check what we are getting:
    fileName = file_base.format(i)
    print(fileName)
   
    print("------Iteration Ends--------")

  # // Save the file 
    with open(fileName, 'w', encoding='utf-8') as f:
     json.dump(data, f, ensure_ascii=False, indent=4)
    files.download(fileName)
# Out:
# ------Iteration Starts--------
# JWR5
# https://api.ons.gov.uk/timeseries/JWR5/dataset/LMS/data
# ...
